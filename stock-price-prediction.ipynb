# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, LSTM, InputLayer, Bidirectional, Input, Dense
from tensorflow.keras.ops import expand_dims

# %%
class CustomLayer(Layer):
    def __init__(self, units_array):
        super(CustomLayer, self).__init__(name="custom_layer")
        self.units_array = units_array
    def call(self, X):
        X = expand_dims(X, 2)
        x = LSTM(10)(X[:,0,:, :])
        print(len(self.units_array))
        
#         for i in range(1, len(self.units_array)):
#             x = LSTM(self.units_array[i])(X[:, i, :, :], initial_state=x)
#         op = LSTM(12)(X[:, 0, :, :], initial_state=x)
        return op

# %%
def createModel(units_array, prev_datas, parameters, num_classes):
    X = Input(shape=(prev_datas, 1, parameters), name="input")
    x = LSTM(units_array[0])(X[:, 0, :, :])
#     y = LSTM(units_array[1])(X[:, 1, :, :], initial_state=x)
    for i in range(1, len(units_array)):
        y = LSTM(units_array[i])(X[:, 1, :, :], initial_state=x)
        x = y
    y = Dense(10, activation="relu")(y)
    op = Dense(3, activation="softmax")(y)
    return Model(X, op)

model = createModel([10, 20, 30, 40, 20], 5, 12, 3).summary()
# Out:
# Model: "functional_51"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 5, 1, 12)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_54         │ (None, 1, 12)     │          0 │ input[0][0]       │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_55         │ (None, 1, 12)     │          0 │ input[0][0]       │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_110 (LSTM)     │ (None, 10)        │        920 │ get_item_54[0][0] │
# ...
